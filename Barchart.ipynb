# %%
person = c(5,3,10,6,4)
Food = c("Kacchi", "Morog Polao", "Khichuri", "Fuchka", "Tehari")

# %%
barplot(person1,names.arg = Food, main ="Fevourite Food Percentage", xlab = "Fig. Food", horiz = TRUE)
# Out:
# Plot with title "Sports Percentage"

# %%
person1 = c(10,4,5,11,10)
sports =c("Footbal","Hockey","Cricket","Basketball","Badminton")

# %%
barplot(person, names.arg = c("Footbal","Hockey","Cricket","Basketball","Badminton"), 
        main ="Sports Percentage", xlab = "Fig. Sports")
# Out:
# Plot with title "Fevourite Food Percentage"
